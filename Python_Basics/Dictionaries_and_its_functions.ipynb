# %% [markdown]
# <a href="https://colab.research.google.com/github/salmanakhtar57/Python-Programming/blob/main/Python_Basics/Dictionaries_and_its_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Dictionary is nothing but key value pairs.
d1 = {}
print(type(d1))
# Out:
# <class 'dict'>

# %%
#print(type[d1])
#The value of dictionary can be a dictionary, a list or a tupple. Keys should be immutable.
d2 = {"Salman":"Python",
      "Hassan":"Java", "Qamar":"PHP",
      "Maken":{"B":"Yougurt", "L":"Egg"}}
d2["Ali"] = "BMW"
d2[512] = "UK"
del d2["Ali"]

#print(d2["Maken"]["B"])
print(d2)
# Out:
# {'Salman': 'Python', 'Hassan': 'Java', 'Qamar': 'PHP', 'Maken': {'B': 'Yougurt', 'L': 'Egg'}, 512: 'UK'}

# %%
d3 = {"Salman":"Python",
      "Hassan":"Java",
      "Qamar":"PHP",
      "Maken":{"B":"Yougurt", "L":"Egg"}}
print(d2.copy())
# Out:
# {'Salman': 'Python', 'Hassan': 'Java', 'Qamar': 'PHP', 'Maken': {'B': 'Yougurt', 'L': 'Egg'}, 512: 'UK'}

# %%
d2 = d3
print(d3.copy())
# Out:
# {'Salman': 'Python', 'Hassan': 'Java', 'Qamar': 'PHP', 'Maken': {'B': 'Yougurt', 'L': 'Egg'}}

# %%
print(d3.get("Qamar"))
# Out:
# PHP

# %%
d3.update({"Alina":"Coffee"})
print(d3)
# Out:
# {'Salman': 'Python', 'Hassan': 'Java', 'Qamar': 'PHP', 'Maken': {'B': 'Yougurt', 'L': 'Egg'}, 'Alina': 'Coffee'}

# %%
print(d2.keys())
# Out:
# dict_keys(['Salman', 'Hassan', 'Qamar', 'Maken', 'Alina'])

# %%
print(d3.items())
# Out:
# dict_items([('Salman', 'Python'), ('Hassan', 'Java'), ('Qamar', 'PHP'), ('Maken', {'B': 'Yougurt', 'L': 'Egg'}), ('Alina', 'Coffee')])

# %%
B = [2, 3, 1, 4, 7, 5]

B.sort()

print(B)
# Out:
# [1, 2, 3, 4, 5, 7]
