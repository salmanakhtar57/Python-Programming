# %% [markdown]
# <a href="https://colab.research.google.com/github/salmanakhtar57/Python-Programming/blob/main/Python_Basics/Puthon_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
print("Variables", 'variables')
print(123)
# Out:
# Variables variables
# 123

# %%
num1 = "Toronto"
num2 = "Tokyo"

# %%
print(num1)
# Out:
# Toronto

# %%
Vehari = 'Lahore'
Lahore = "Islamabad"

# %%
print(Vehari)
print(Lahore)
# Out:
# Lahore
# Islamabad

# %%
a = "abc"
b= "xyz"

# %%
print(a)
# Out:
# abc

# %%
f = a

# %%
print(f)
# Out:
# abc

# %%
num3 = f

# %%
print(num3)
# Out:
# abc

# %%
a = "hhh"

# %%
print(f)
# Out:
# abc
